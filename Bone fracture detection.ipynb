# %%
import os
from IPython import display
from IPython.display import Image, display

# %%
HOME = os.getcwd()

# %%
# !pip install ultralytics==8.0.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.9 MB/s eta 0:00:00
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=53021bf378c8ada5a4dab6e75546d2f2941d3b7a6898484b08a954c545d3c432
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2BqrsoBpeBbbLrjr7hWC")
project = rf.workspace("fracture-uofxm").project("bone-fracture-detection-ivsy6")
dataset = project.version(1).download("yolov5")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 6.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=292de0f4d77ee3e845e8fcbf65aa03229f82b8b8f0b7b5fae1d3c59eda42fe43
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {HOME}


# !yolo task=detect mode=train model=yolov8x.pt data=/content/datasets/Bone-fracture-detection/data.yaml epochs=70 imgsz=640
# Out:
# /content
# ...
# 100% 131M/131M [00:02<00:00, 53.8MB/s]
#
# ...

# %%
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=900)
# Out:
# /content

# %%
# %cd {HOME}

Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# validate custom model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/datasets/Bone-fracture-detection/data.yaml
# Out:
# /content
# 2023-05-06 10:32:18.606258: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 10:32:20.428413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/datasets/Bone-fracture-detection/valid/labels.cache... 99 images, 0 backgrounds, 0 corrupt: 100% 99/99 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:09<00:00,  1.29s/it]
# ...

# %% [markdown]
# **inference with custom model**

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/datasets/Bone-fracture-detection/test/images
# Out:
# /content
# 2023-05-06 10:33:34.817069: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 10:33:35.822954: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/156 /content/datasets/Bone-fracture-detection/test/images/all_0_1142_png.rf.4ba726be944734d8df455b77cc49a54f.jpg: 640x640 1 Fracture, 79.3ms
# image 2/156 /content/datasets/Bone-fracture-detection/test/images/all_0_1285_png.rf.199b6d0816f2fddd475e6c3e6047ebdf.jpg: 640x640 4 Fractures, 55.2ms
# ...

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=https://www.medindia.net/images/patientinfo/300x250/hand-fractures.jpg
# Out:
# 2023-05-06 10:42:55.347402: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 10:42:56.800851: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 100% 14.4k/14.4k [00:00<00:00, 120kB/s]
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/hand-fractures.jpg: 544x640 1 Fracture, 71.6ms
# Speed: 0.5ms pre-process, 71.6ms inference, 109.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
Image("/content/runs/detect/predict3/hand-fractures.jpg")

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=https://image.shutterstock.com/display_pic_with_logo/1444166/178864445/stock-photo-x-ray-of-both-broken-legs-fracture-tibia-and-fibula-178864445.jpg
# Out:
# 2023-05-06 10:53:02.675277: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 10:53:03.690172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 100% 26.2k/26.2k [00:00<00:00, 60.0MB/s]
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/stock-photo-x-ray-of-both-broken-legs-fracture-tibia-and-fibula-178864445.jpg: 640x576 3 Fractures, 70.1ms
# Speed: 0.5ms pre-process, 70.1ms inference, 136.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6

# %%
Image("/content/runs/detect/predict6/stock-photo-x-ray-of-both-broken-legs-fracture-tibia-and-fibula-178864445.jpg")

# %%
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=https://ota.org/sites/files/2020-05/PE3731f04.png
# Out:
# 2023-05-06 11:00:55.642049: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-06 11:00:56.702988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# 100% 65.3k/65.3k [00:00<00:00, 387kB/s]
# Ultralytics YOLOv8.0.0 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Fusing layers...
# Model summary: 268 layers, 68124531 parameters, 0 gradients, 257.4 GFLOPs
# image 1/1 /content/PE3731f04.png: 384x640 1 Fracture, 97.4ms
# Speed: 0.5ms pre-process, 97.4ms inference, 130.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict7

# %%
Image("/content/runs/detect/predict7/PE3731f04.png")
